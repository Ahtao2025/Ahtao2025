# %% [markdown]
# ## Elbow method: Determine the range of numbers of clusters

# %%
import sklearn.cluster as cluster
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns


#  drop the few missing values in data frame
df = combined_data.fillna(0)


#  check again about missing values
print(np.isnan(df).sum(axis=0))
# try different number of clusters
k_values = range(1, 15)
sse = []  # storing SSE values(Sum of Squared Distances)

for k in k_values:
    kmeans = cluster.KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df)
    sse.append(kmeans.inertia_)

 
#Apply Elbow method to determine the suitable number of clusters
plt.figure(figsize=(8, 5))
plt.plot(k_values, sse, marker='o')
plt.title('Elbow Method for Optimal k', fontsize=14)
plt.xlabel('Number of Clusters (k)', fontsize=12)
plt.ylabel('Sum of Squared Distances (SSE)', fontsize=12)
plt.show()
# Out:
# Id                  0
# Navstatus           0
# Channelnumber       0
# Specialmanoeuvre    0
# is_alternating      0
# Slotoffset          0
# Slotnumber          0
# Slotincrement       0
# Sog                 0
# Toa                 0
# SyncError_TS        0
# Interval_Bias       0
# NewTimeSlot_Used    0
# STO_Deviation       0
# SlotChange          0
# dtype: int64

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

#  PCA: reduce the dimension of data to 2D
pca = PCA(n_components= 0.9)
pca_features = pca.fit_transform(df)

# plot the distribution of datas
plt.figure(figsize=(8, 6))
plt.scatter(pca_features[:, 0], pca_features[:, 1], alpha=0.6, s=10)
plt.title('2D Data Points Visualization (PCA)')
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.show()
